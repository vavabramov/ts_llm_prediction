# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt

file = '/Users/vav/Work/thesis_2025/ts_llm_prediction/SPY_full.csv'
RS=42

# %%
df = pd.read_csv(file)
df['Date'] = pd.to_datetime(df['Date']).dt.date
df = df.set_index('Date')
df.head()
# Out:
#                Close   Volume  Dividends  Stock Splits  in_sp500  Close_SMA_7  \
# Date
# 2000-01-06  137.7500  6227200        0.0           0.0         1   143.323661
# 2000-01-07  145.7500  8066500        0.0           0.0         1   143.171875
# 2000-01-10  146.2500  5741700        0.0           0.0         1   143.116071
# 2000-01-11  144.5000  7503700        0.0           0.0         1   142.776786
# 2000-01-12  143.0625  6907700        0.0           0.0         1   142.437500
#
#             Close_SMA_50  Close_SMA_200  Volume_SMA_7  Volume_SMA_50  ...  \
# Date                                                                  ...
# 2000-01-06    140.855625     135.102188  6.353457e+06      6163246.0  ...
# 2000-01-07    141.168125     135.183437  7.077100e+06      6215910.0  ...
# 2000-01-10    141.401875     135.271875  7.377157e+06      6120550.0  ...
# 2000-01-11    141.551875     135.338594  7.995871e+06      6050852.0  ...
# 2000-01-12    141.701875     135.401563  7.816357e+06      6108876.0  ...
#
#             MSFT_Close_SMA_200  JPM_Close  JPM_Volume  JPM_Dividends  \
# Date
# 2000-01-06           45.205312  47.625000     8369250            0.0
# 2000-01-07           45.258984  48.500000     6571950            0.0
# 2000-01-10           45.316953  47.666668     4723500            0.0
# 2000-01-11           45.359453  46.541668     8405550            0.0
# 2000-01-12           45.391484  46.833332     7271850            0.0
#
#             JPM_Close_SMA_7  JPM_Close_SMA_50  JPM_Close_SMA_200  delistings  \
# Date
# 2000-01-06        49.422619         52.860208          53.026406         0.0
# 2000-01-07        48.964286         52.726875          52.997240         0.0
# 2000-01-10        48.339286         52.499375          52.967240         0.0
# 2000-01-11        47.589286         52.266875          52.925781         0.0
# 2000-01-12        47.339286         52.089375          52.886823         0.0
#
#             listings  splits
# Date
# 2000-01-06       1.0     0.0
# 2000-01-07       0.0     0.0
# 2000-01-10       0.0     0.0
# 2000-01-11       0.0     0.0
# 2000-01-12       0.0     0.0
#
# [5 rows x 103 columns]

# %%
# Missing Values Check
nulls = df.isnull().sum().reset_index()
nulls[nulls[0]>0]
# Out:
# Empty DataFrame
# Columns: [index, 0]
# Index: []

# %% [markdown]
# # Stationarity

# %%
# Shift SPY price by 1, to predict 1d ahead

# Perform ADF test
result = adfuller(df['Close'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])
for key, value in result[4].items():
    print('Critical Values:')
    print(f'{key}, {value}')
# Plot the time series
plt.figure(figsize=(10, 6))
plt.plot( df['Close'], label='SPY')
plt.title('Non-Stationary SPY')
plt.legend()
plt.show()
# Out:
# ADF Statistic: 1.9978033206994503
# p-value: 0.9986700900472227
# Critical Values:
# 1%, -3.4313879129264944
# Critical Values:
# 5%, -2.861998666151273
# Critical Values:
# 10%, -2.5670141449564965

# %%
# Differencing to make the series stationary
diff_series = np.diff(df['Close'], n=1)
# Perform ADF test on differenced series
result_diff = adfuller(diff_series)
print('ADF Statistic (Differenced):', result_diff[0])
print('p-value (Differenced):', result_diff[1])
for key, value in result_diff[4].items():
    print('Critical Values (Differenced):')
    print(f'{key}, {value}')
# Plot the differenced time series
plt.figure(figsize=(10, 6))
plt.plot( diff_series, label='SPY Diff')
plt.title('Stationary SPY After Differencing (n=1)')
plt.legend()
plt.show()
# Out:
# ADF Statistic (Differenced): -16.125826162490515
# p-value (Differenced): 4.8432835044545275e-29
# Critical Values (Differenced):
# 1%, -3.4313879129264944
# Critical Values (Differenced):
# 5%, -2.861998666151273
# Critical Values (Differenced):
# 10%, -2.5670141449564965

# %%
df['target_diff'] = [np.nan] + diff_series.tolist()
df['target_diff'] = df['target_diff'].shift(-7)
df = df.dropna()
df.head()
# Out:
#                Close   Volume  Dividends  Stock Splits  in_sp500  Close_SMA_7  \
# Date
# 2000-01-06  137.7500  6227200        0.0           0.0         1   143.323661
# 2000-01-07  145.7500  8066500        0.0           0.0         1   143.171875
# 2000-01-10  146.2500  5741700        0.0           0.0         1   143.116071
# 2000-01-11  144.5000  7503700        0.0           0.0         1   142.776786
# 2000-01-12  143.0625  6907700        0.0           0.0         1   142.437500
#
#             Close_SMA_50  Close_SMA_200  Volume_SMA_7  Volume_SMA_50  ...  \
# Date                                                                  ...
# 2000-01-06    140.855625     135.102188  6.353457e+06      6163246.0  ...
# 2000-01-07    141.168125     135.183437  7.077100e+06      6215910.0  ...
# 2000-01-10    141.401875     135.271875  7.377157e+06      6120550.0  ...
# 2000-01-11    141.551875     135.338594  7.995871e+06      6050852.0  ...
# 2000-01-12    141.701875     135.401563  7.816357e+06      6108876.0  ...
#
#             JPM_Close  JPM_Volume  JPM_Dividends  JPM_Close_SMA_7  \
# Date
# 2000-01-06  47.625000     8369250            0.0        49.422619
# 2000-01-07  48.500000     6571950            0.0        48.964286
# 2000-01-10  47.666668     4723500            0.0        48.339286
# 2000-01-11  46.541668     8405550            0.0        47.589286
# 2000-01-12  46.833332     7271850            0.0        47.339286
#
#             JPM_Close_SMA_50  JPM_Close_SMA_200  delistings  listings  splits  \
# Date
# 2000-01-06         52.860208          53.026406         0.0       1.0     0.0
# 2000-01-07         52.726875          52.997240         0.0       0.0     0.0
# 2000-01-10         52.499375          52.967240         0.0       0.0     0.0
# 2000-01-11         52.266875          52.925781         0.0       0.0     0.0
# 2000-01-12         52.089375          52.886823         0.0       0.0     0.0
#
#             target_diff
# Date
# 2000-01-06     -1.15625
# 2000-01-07      1.18750
# 2000-01-10     -2.25000
# 2000-01-11     -0.31250
# 2000-01-12     -4.09375
#
# [5 rows x 104 columns]

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.ensemble import RandomForestRegressor

X = df.drop(columns = ['target_diff', 'Histogram'])
y = df['target_diff']
# Remove highly correlated features
corr_matrix = X.corr().abs()
upper =corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
to_drop = [column for column in upper.columns if any(upper[column] > 0.9)]

X_reduced = X.drop(columns=to_drop)

# Train a Random Forest model
model = RandomForestRegressor(random_state=RS)
model.fit(X_reduced, y)


# Get feature importance
importances = model.feature_importances_
feature_names = X_reduced.columns
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)


importance_df.plot(kind='bar', x='Feature',y='Importance', figsize=(14, 8))
plt.title('Feature Importance SPY (t+7 prediction)')
plt.show()

# %%
importance_df
# Out:
#             Feature  Importance
# 6              MACD    0.104196
# 5             RSI_7    0.064775
# 0             Close    0.059462
# 16         GE_Close    0.054733
# 26        XOM_Close    0.054323
# 9        NVDA_Close    0.052534
# 27       XOM_Volume    0.049233
# 19       WMT_Volume    0.047264
# 17        GE_Volume    0.045632
# 1            Volume    0.045115
# 7       AAPL_Volume    0.043109
# 29      AMZN_Volume    0.041998
# 10      NVDA_Volume    0.041665
# 33       JPM_Volume    0.041499
# 22         C_Volume    0.040134
# 31      MSFT_Volume    0.037737
# 12     GOOGL_Volume    0.037644
# 21          C_Close    0.037507
# 14      AVGO_Volume    0.037075
# 24      META_Volume    0.034343
# 11   NVDA_Dividends    0.003910
# 37           splits    0.003545
# 13  GOOGL_Dividends    0.003432
# 32   MSFT_Dividends    0.002697
# 36         listings    0.002619
# 18     GE_Dividends    0.002441
# 15   AVGO_Dividends    0.002107
# 34    JPM_Dividends    0.001807
# 2         Dividends    0.001705
# 20    WMT_Dividends    0.001667
# 28    XOM_Dividends    0.001521
# 23      C_Dividends    0.001204
# 8    AAPL_Dividends    0.000657
# 35       delistings    0.000408
# 4          in_sp500    0.000251
# 25   META_Dividends    0.000050
# 3      Stock Splits    0.000000
# 30   AMZN_Dividends    0.000000
